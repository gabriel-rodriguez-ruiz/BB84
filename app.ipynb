# %%
import pandas as pd
from load_data import assign_roles, load_data
from characters import Alice, Bob
from pathlib import Path
import matplotlib.pyplot as plt
import sys
import matplotlib
import panel as pn
import hvplot.pandas
from draw_table import draw_table, get_qbit, make_table, show_character, change_table_style
import numpy as np
import io

pn.extension(sizing_mode='scale_both')
pn.extension('tabulator')
pn.extension('katex', 'mathjax')
pn.extension()
#%matplotlib widget
pn.widgets.Tabulator.theme = 'materialize'

file_input = pn.widgets.FileInput(accept=".csv")
data_folder = Path("Data/")

def load_file_name(file_input):
    if file_input is not None:
        return data_folder / file_input
active_load_file_name = pn.bind(load_file_name, file_input.param.filename)

def get_columns(file_input):
    if file_input is not None:
        global table, checkbox_group
        file_to_open = load_file_name(file_input)
        eavesdropping = False
        Alice_list, Bob_list, Eve_list = assign_roles(file_to_open, eavesdropping)
        for i in range(len(Alice_list)):
            Alice_list[i].send_to_Bob(Eve_list[i], Bob_list[i])  
        table, qubit_df, checkbox_group = make_table(Alice_list, Bob_list, Eve_list)
        globals()['table'] = table
        globals()['checkbox_group'] = checkbox_group
        return table, qubit_df, checkbox_group
    else:
        return (None, None, None)

def get_table(f):
    global table
    table = active_get_columns()[0]
    return table

def get_checkbox_group(f):
    global checkbox
    checkbox = active_get_columns()[2]
    return checkbox
    
active_get_columns = pn.bind(get_columns, file_input.param.filename)
active_get_checkbox_group = pn.bind(get_checkbox_group, file_input.param.filename)
active_get_table = pn.bind(get_table, file_input.param.filename)

table, qubit_df, checkbox_group = active_get_columns()

#dashboard = pn.Column(file_input, active_load_file_name, active_get_checkbox_group, active_get_table, sizing_mode='scale_both')
dashboard = pn.Column(file_input, active_load_file_name, checkbox_group, table, sizing_mode='scale_both')

# Show the dashboard
dashboard.servable()
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='d9130592-1e1f-4d15-bfb1-ddac911db040'>
#   <div id="e4220df7-c215-4d4a-a6f8-293bf25a2fd9" data-root-id="d9130592-1e1f-4d15-bfb1-ddac911db040" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
import pandas as pd
from load_data import assign_roles, load_data
from characters import Alice, Bob
from pathlib import Path
import matplotlib.pyplot as plt
import sys
import matplotlib
import panel as pn
import hvplot.pandas
from draw_table import draw_table, get_qbit, make_table, show_character, change_table_style
import numpy as np

pn.extension(sizing_mode='scale_both')
pn.extension('tabulator')
pn.extension('katex', 'mathjax')
pn.extension()
#%matplotlib widget
pn.widgets.Tabulator.theme = 'materialize'


data_folder = Path("Data/")

######################################################
#file_name = "BB84 26_06_2025-26_06_2025 .csv"
######################################################

file_input = pn.widgets.FileInput(accept=".csv")
data_folder = Path("Data/")

file_to_open = pn.rx(data_folder / file_input

eavesdropping = False

Alice_list, Bob_list, Eve_list = assign_roles(file_to_open, eavesdropping)

for i in range(len(Alice_list)):
    Alice_list[i].send_to_Bob(Eve_list[i], Bob_list[i])
    
table, qubit_df, checkbox_group = make_table(Alice_list, Bob_list, Eve_list)



column = pn.Column(checkbox_group, table, sizing_mode='scale_both').servable()
# Out:
# NoneType

# %%
file_input = pn.widgets.FileInput(accept=".csv")
def get_file_input(file):
    if file is not None:
        return file
filename_rx = pn.rx(get_file_input)(file_input.param.filename)
pn.Column(filename_rx)
# Out:
# Column
#     [0] Row
#         [0] Row
#             [0] WidgetBox
#                 [0] FileInput(accept='.csv')
#             [1] ParamFunction(function, _pane=Str, defer_load=False)

# %%
# Out:
# <div id='8ad869c4-3814-4b3b-8483-17f367d275a8'>
#   <div id="e1240ed6-01e8-4cb0-9a8f-3f6b287506e9" data-root-id="8ad869c4-3814-4b3b-8483-17f367d275a8" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...
